# %% [markdown]
# Scrape www.filmtotaal.nl
# Save to s3 as a series of files
# stars;title;text

# %%
import json
import pandas as pd
import re
import numpy as np
import os
# import stringdist
import boto3 
import matplotlib.pyplot as plt
# import operator
import datetime
from dateutil import tz
from pyspark.sql.types import StringType
from pyspark.sql.functions import udf
import shutil


import urllib.request
from bs4 import BeautifulSoup
from dateutil import tz

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.amazonaws:aws-java-sdk:1.10.34,org.apache.hadoop:hadoop-aws:2.6.0 pyspark-shell'
os.environ['AWS_ACCESS_KEY_ID'] = 'AKIAI6V3AA63EVBV5IXA'
os.environ['AWS_SECRET_ACCESS_KEY'] = '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'

# sc.stop()

import pyspark
sc = pyspark.SparkContext('local[*]')

from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)
hadoopConf = sc._jsc.hadoopConfiguration()
hadoopConf.set("fs.s3.impl", "org.apache.hadoop.fs.s3native.NativeS3FileSystem")
hadoopConf.set("fs.s3.awsAccessKeyId", "AKIAI6V3AA63EVBV5IXA")
hadoopConf.set("fs.s3.awsSecretAccessKey", "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")

# %% [markdown]
# ## (Remove and re)make folder

# %%
# Remove file or folder

def rempath (path):
    try:
        shutil.rmtree(path)
    except OSError:
        pass

    try:
        os.remove(path)
    except OSError:
        pass

# %%
for pagenum in range(5):

    url = 'https://www.filmtotaal.nl/recensie?page=' + str(pagenum)
    print(url)

    # Download
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "html5lib")
    soup = str(soup).split('\n')


    # Strip start and end lines
    rgxstart = '<div class="layout-wrap">'
    rgxstop = 'start right sidebar'

    startline = []
    stopline = []
    for s in range(len(soup)):
        if not re.search(rgxstart, soup[s]) is None:
            startline.append(s)
        if not re.search(rgxstop, soup[s]) is None:
            stopline.append(s)

    if not len(startline) == 1:
        print ('ERROR: Startline not found.')
    elif len(stopline) == 0:
        print ('ERROR: Stopline not found.')
    else:
        soup = soup[startline[0]:stopline[0]]


    # Extract info
    rgxtitle = 'class="title"'
    rgxtxt = 'class="bite"'
    rgxstars = 'div class="stars'

    title = []
    txt = []
    stars = []

    for s in range(len(soup)):
        if not re.search(rgxtitle, soup[s]) is None:
            title_ = re.findall(r"<h2>.*</h2>", soup[s])[-1].strip('</?h2>')
            title.append(title_)
        elif not re.search(rgxstars, soup[s]) is None:
            stars_ = 0
            for i in range(s+1,s+7):
                if not re.search('whole',soup[i]) is None:
                    stars_ += 1
                elif not re.search('half',soup[i]) is None:
                    stars_ += 0.5
            stars.append(stars_)

        elif not re.search(rgxtxt, soup[s]) is None:
            txt_ = soup[s].strip(' ?(<p class="bite">|</p>)')
            txt.append(txt_)


    # Save to s3
#     if len(title) == len(stars) and len(title) == len(txt):
#         res = pd.DataFrame(
#             {'title': title,
#              'stars': stars,
#              'txt': txt
#             }) 

#         fileout = re.sub('=', '-', url.split('recensie?')[1]) + '.csv'

#         rempath(fileout)
#         res.to_csv(fileout, sep=';', na_rep='', float_format=None, columns=None, header=True, index=False,\
#                             index_label=None, mode='w', encoding=None, compression=None, quoting=None, quotechar='"',\
#                             line_terminator='\n', chunksize=None, tupleize_cols=None, date_format=None, \
#                             doublequote=True, escapechar=None, decimal='.')

#         bucket_name = 'filmtotaal'
#         s3 = boto3.client('s3')
#         s3.upload_file(fileout, bucket_name, fileout)

#         rempath(fileout)

#     else:
#         print ('ERROR: Unequal list lengths')
# Out:
# https://www.filmtotaal.nl/recensie?page=0
# https://www.filmtotaal.nl/recensie?page=1
# https://www.filmtotaal.nl/recensie?page=2
# https://www.filmtotaal.nl/recensie?page=3
# https://www.filmtotaal.nl/recensie?page=4
# https://www.filmtotaal.nl/recensie?page=5
# https://www.filmtotaal.nl/recensie?page=6
# https://www.filmtotaal.nl/recensie?page=7
# https://www.filmtotaal.nl/recensie?page=8
# https://www.filmtotaal.nl/recensie?page=9
# https://www.filmtotaal.nl/recensie?page=10
# https://www.filmtotaal.nl/recensie?page=11
# https://www.filmtotaal.nl/recensie?page=12
# https://www.filmtotaal.nl/recensie?page=13
# https://www.filmtotaal.nl/recensie?page=14
# https://www.filmtotaal.nl/recensie?page=15
# https://www.filmtotaal.nl/recensie?page=16
# https://www.filmtotaal.nl/recensie?page=17
# https://www.filmtotaal.nl/recensie?page=18
# https://www.filmtotaal.nl/recensie?page=19
# https://www.filmtotaal.nl/recensie?page=20
# https://www.filmtotaal.nl/recensie?page=21
# https://www.filmtotaal.nl/recensie?page=22
# https://www.filmtotaal.nl/recensie?page=23
# https://www.filmtotaal.nl/recensie?page=24
# https://www.filmtotaal.nl/recensie?page=25
# https://www.filmtotaal.nl/recensie?page=26
# https://www.filmtotaal.nl/recensie?page=27
# https://www.filmtotaal.nl/recensie?page=28
# https://www.filmtotaal.nl/recensie?page=29
# https://www.filmtotaal.nl/recensie?page=30
# https://www.filmtotaal.nl/recensie?page=31
# https://www.filmtotaal.nl/recensie?page=32
# https://www.filmtotaal.nl/recensie?page=33
# https://www.filmtotaal.nl/recensie?page=34
# https://www.filmtotaal.nl/recensie?page=35
# https://www.filmtotaal.nl/recensie?page=36
# https://www.filmtotaal.nl/recensie?page=37
# https://www.filmtotaal.nl/recensie?page=38
# https://www.filmtotaal.nl/recensie?page=39
# https://www.filmtotaal.nl/recensie?page=40
# https://www.filmtotaal.nl/recensie?page=41
# https://www.filmtotaal.nl/recensie?page=42
# https://www.filmtotaal.nl/recensie?page=43
# https://www.filmtotaal.nl/recensie?page=44
# https://www.filmtotaal.nl/recensie?page=45
# https://www.filmtotaal.nl/recensie?page=46
# https://www.filmtotaal.nl/recensie?page=47
# https://www.filmtotaal.nl/recensie?page=48
# https://www.filmtotaal.nl/recensie?page=49
# https://www.filmtotaal.nl/recensie?page=50
# https://www.filmtotaal.nl/recensie?page=51
# https://www.filmtotaal.nl/recensie?page=52
# https://www.filmtotaal.nl/recensie?page=53
# https://www.filmtotaal.nl/recensie?page=54
# https://www.filmtotaal.nl/recensie?page=55
# https://www.filmtotaal.nl/recensie?page=56
# https://www.filmtotaal.nl/recensie?page=57
